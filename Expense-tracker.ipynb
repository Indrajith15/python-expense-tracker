# %%
import json

try:
    with open("expenses.txt", "r") as file:
        expenses = json.load(file)
except:
    expenses=[]

def save_expenses():
    with open("expenses.txt", "w") as file:
        json.dump(expenses, file)
while True:
    print("\n********TO DO LIST********")
    print("1. Add Expense")
    print("2. View View Expense")
    print("3. Show Total Expense")
    print("4. Exit")

    choice = int(input("Enter your choice:"))
    if choice == 1:
        date = input("Enter the date (DD-MM-YYYY):")
        expense_type = input("Enter the category or the name of the expense:")
        amount= float(input("Enter the amount:"))
        expense = {"date": date, "category": expense_type, "amount": amount}
        expenses.append(expense)
        save_expenses()
        print("Expense added successfully")

    elif choice == 2:
        if len(expenses) == 0:
            print("No data available")
        else:
            for i, expense in enumerate(expenses):
                print(f"{i+1}. {expense}")
    elif choice == 3:
        total_expense = 0
        for expense in expenses:
            total_expense += expense["amount"]
        print(total_expense)
    elif choice == 4:
        print("Thank you")
        break
    else:
        print("Invalid Choice")
# Out:
# ********TO DO LIST********
# 1. Add Expense
# 2. View View Expense
# 3. Show Total Expense
# 4. Exit
# Enter your choice: 1
# Enter the date (DD-MM-YYYY): 25-06-2026
# Enter the category or the name of the expense: food
# Enter the amount: 900
# Expense added successfully
#
# ********TO DO LIST********
# 1. Add Expense
# 2. View View Expense
# 3. Show Total Expense
# 4. Exit
# Enter your choice: 1
# Enter the date (DD-MM-YYYY): 25-06-2026
# Enter the category or the name of the expense: cab
# Enter the amount: 1500
# Expense added successfully
#
# ********TO DO LIST********
# 1. Add Expense
# 2. View View Expense
# 3. Show Total Expense
# 4. Exit
# Enter your choice: 2
# 1. {'date': '25-06-2026', 'category': 'food', 'amount': 900.0}
# 2. {'date': '25-06-2026', 'category': 'cab', 'amount': 1500.0}
#
# ********TO DO LIST********
# 1. Add Expense
# 2. View View Expense
# 3. Show Total Expense
# 4. Exit
# Enter your choice: 3
# 2400.0
#
# ********TO DO LIST********
# 1. Add Expense
# 2. View View Expense
# 3. Show Total Expense
# 4. Exit
# Enter your choice: 4
# Thank you
